# %%
atuple = (3,3,4,5,6)
count = atuple.count(3)
print(count)
# Out:
# 2

# %%
# difference ? list is changeable , tuple is not 
alist = [1,2,3,4]
atuple = (1,3,4,5)

print(atuple)
print(alist)
# Out:
# (1, 3, 4, 5)
# [1, 2, 3, 4]

# %%
alist[0] = "Ashish"
alist
# Out:
# ['Ashish', 2, 3, 4]

# %%
atuple[0] = 'ash'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 atuple[0] = 'ash'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# convert tuple to list 
print(type(atuple))
# Out:
# <class 'tuple'>

# %%
print(type(list(atuple)))
# Out:
# <class 'list'>

# %%
v = list(atuple)
v[0] = 'ash'
v
a = tuple(v)
a
# Out:
# ('ash', 3, 4, 5)

# %%
a[2]
# Out:
# 4
