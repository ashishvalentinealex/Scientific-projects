# %%
D = dict()
D
# Out:
# {}

# %%
D['name'] = 'Ash'
D['age'] = [25,30]
D
# Out:
# {'name': 'Ash', 'age': [25, 30]}

# %%
E = {'name':'ashi','agerange':[6,30]}
E
# Out:
# {'name': 'ashi', 'agerange': [6, 30]}

# %%
D['name']
# Out:
# 'Ash'

# %%
D.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
'name' in D
# Out:
# True

# %%
'Name' in D
# Out:
# False

# %%
D.values()
# Out:
# dict_values(['Ash', [25, 30]])

# %%
D.items()
# Out:
# dict_items([('name', 'Ash'), ('age', [25, 30])])

# %%
w = dict()
firstNum = int(input())
secondNum = int(input())

w['firstNum']  = firstNum
w['secondNum']  = secondNum
w['product'] = firstNum*secondNum

w
# Out:
# {'firstNum': 3, 'secondNum': 4, 'product': 12}

# %%
w.items()
# Out:
# dict_items([('firstNum', 3), ('secondNum', 4), ('product', 12)])
