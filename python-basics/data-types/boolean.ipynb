# %%
boolTrue = True
strTrue = 'True'
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# boolTrue   bool    True
# strTrue    str     True

# %%
4 == 4
# Out:
# True

# %%
4>5
# Out:
# False

# %%
4<5
# Out:
# True

# %%
4<=5
# Out:
# True

# %%
4<4
# Out:
# False

# %%
4!=5
# Out:
# True

# %%
out = 5 ==3
print(out)
# Out:
# False

# %%
14>5 and 14<17
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool('0')
# Out:
# True

# %%
triplet1 = int(input())
print(triplet1)
triplet2 = int(input())
print(triplet2)
triplet3 = int(input())
print(triplet3)


out = triplet1**2 + triplet2**2 == triplet3**2
print(out)
# Out:
# 5
# 7
# 8
# False
