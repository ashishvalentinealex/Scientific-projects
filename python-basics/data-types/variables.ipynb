# %%
a = 4 
print(a)
# Out:
# 4

# %%
b = 3
b
# Out:
# 3

# %%
d = 'hey there'
e = "Ashish likes R.."
print(d)
print(e)
print(d,e)
print(a,b)
# Out:
# hey there
# Ashish likes R..
# hey there Ashish likes R..
# 4 3

# %%
filter_Order = 2098
data2plot = 3

# %%
print(filter_Order, data2plot)
# Out:
# 2098 3

# %%
t,y = 10,12
print(t,y)
# Out:
# 10 12

# %%
u,i = 2,"jey"
print(u,i)
# Out:
# 2 jey

# %%
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# d              str     hey there
# data2plot      int     3
# e              str     Ashish likes R..
# filter_Order   int     2098
# i              str     jey
# t              int     10
# u              int     2
# y              int     12

# %%
# can overwite variable 
# over-write a variable using a different datatype   

a = 1 
print(a)
a = 2
print(a)
b = "jeyi"
print(b)
b = 2
print(b)
print(a+b)
# Out:
# 1
# 2
# jeyi
# 2
# 4

# %%
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     2
# b              int     2
# d              str     hey there
# data2plot      int     3
# e              str     Ashish likes R..
# filter_Order   int     2098
# i              str     jey
# t              int     10
# u              int     2
# y              int     12
