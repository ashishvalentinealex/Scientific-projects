# %%
x = 1
c = 3.4
z = 2

# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# c          float    3.4
# x          int      1
# z          int      2

# %%
print(x-4)
print(x*c)
# Out:
# -3
# 3.4

# %%
print(c/z)
# Out:
# 1.7

# %%
3**2
# Out:
# 9

# %%
# square root 
9**(1/2)
# Out:
# 3.0

# %%
first_name = "ashish"
last_name = "Valentine"
print(first_name + ' ' + last_name)
# Out:
# ashish Valentine

# %%
first_name*2
# Out:
# 'ashishashish'
