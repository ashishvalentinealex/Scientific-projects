# %% [markdown]
# Write a Python program that:
#
# Takes input for 3 students, one by one.
# For each student, input their name and marks in all three subjects (space-separated).
# Example input for one student:
#
# Enter student data (name math science english): John 80 75 92
#
#
# Stores the data in a dictionary called students, where:
#
# Each key is the student’s name (a string).
#
# Each value is a tuple containing (math, science, english) marks.
#
# Example:
#
# students = {
#     'John': (80, 75, 92),
#     'Mary': (90, 88, 84)
# }
#
#
# Compute the average marks for each student and store it in another dictionary called averages where:
#
# Each key = student name
#
# Each value = average marks (rounded to 2 decimals)
#
# Find and print:
#
# The student with the highest average
#
# Whether that student has scored above 80 in all subjects (print True or False)
#
# The subject-wise topper (who scored highest in each subject)
#
# Expected Output Example
# Enter student data (name math science english): John 80 75 92
# Enter student data (name math science english): Mary 90 88 84
# Enter student data (name math science english): Alex 70 95 89
#
# Averages: {'John': 82.33, 'Mary': 87.33, 'Alex': 84.67}
# Topper: Mary
# Mary has scored above 80 in all subjects: True
# Subject-wise toppers: {'Math': 'Mary', 'Science': 'Alex', 'English': 'John'}
#
# Concepts Tested
# Concept	Where Used
# Variables	Storing names, marks, etc.
# Math Operations	Calculating averages, comparisons
# Boolean Logic	Checking if all marks > 80
# Tuples	Storing marks per student
# Dictionaries	Organizing student and subject data
# Loops & Conditionals	Processing multiple students, finding toppers
